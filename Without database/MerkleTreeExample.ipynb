# %%
from MerkleTree import MerkleTree

# %%
transactions = [chr(97 + i) for i in range(7)]
tree = MerkleTree(transactions)

# %%
tree.draw()

# %%
result, G = tree.get_nodes_for_validation(idx=1, get_graph=True)
G
